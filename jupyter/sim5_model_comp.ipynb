# %% [markdown]
# # Plot model fit comparisons for PEERS data

# %%
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mindstorm import statplot
from dcmr import framework
from dcmr import figures
from dcmr import reports

fit_dir = Path(os.environ['PEERS_FITS']) / 'simple'
fig_dir = Path(os.environ['PEERS_FIGURES']) / 'plots'

os.makedirs(fig_dir, exist_ok=True)
figures.set_style()
# %matplotlib inline

# %% [markdown]
# ## Load model fits

# %%
model_names = [
    'DCMR-Variable',
    'DCMR-NonInteg',
    'DCMR-NonInteg-Focused',
    'DCMR-Focused',
    'CMR-MP16-L',
]
models, temp = framework.get_sim_models('peers2', 'set2', included=model_names)
index = [model_names.index(t) for t in temp]
models = [models[i] for i in index]

xval = framework.read_model_xvals(fit_dir, models, model_names)
xval.groupby('model')['logl_test_list'].mean().sort_values()
# Out:
# model
# DCMR-NonInteg-Focused   -21.299803
# DCMR-NonInteg           -21.294740
# DCMR-Variable           -21.294074
# CMR-MP16-L              -21.284316
# DCMR-Focused            -21.258934
# Name: logl_test_list, dtype: float64

# %% [markdown]
# ## Plot model cross-validation performance

# %%
g = figures.plot_xval_comp(xval, aspect=1.5, height=5)
g.savefig(fig_dir / 'model_comp_xval.pdf')
None
# Out:
# LINO NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Plot best-fitting B parameters by sublayer

# %%
dark = sns.color_palette(
    'ch:start=0, rot=0.5, light=.7, dark=.1, gamma=.6, hue=.5', n_colors=2
)
dark
# Out:
# [(0.8676388027925326, 0.7871647534033639, 0.7634698745829795),
#  (0.2668281999264471, 0.2224082818200638, 0.3359319635796286)]

# %%
light = sns.color_palette(
    'ch:start=0, rot=0.5, light=.7, dark=.1, gamma=.3, hue=.5', n_colors=2
)
light
# Out:
# [(0.9337854080610744, 0.886668854426149, 0.8727957979900954),
#  (0.5231454706076213, 0.4636364754756973, 0.6157232084815651)]

# %%
ur_model = models[model_names.index("DCMR-Focused")]
fit = framework.read_model_fits(fit_dir, [ur_model], ["DCMR-Focused"])
B_names = [
    'B_enc_loc',
    'B_enc_use',
    'B_rec_loc',
    'B_rec_use',
]
B_subset = pd.melt(
    fit[B_names].reset_index(),
    id_vars='subject', 
    value_vars=B_names,
    var_name='parameter',
    value_name='value',
)
fit[B_names].reset_index()
# Out:
#             model  subject  B_enc_loc  B_enc_use  B_rec_loc  B_rec_use
# 0    DCMR-Focused       63   0.363932   0.754546   0.718676        1.0
# 1    DCMR-Focused       64   0.010815   0.027228   0.546527        1.0
# 2    DCMR-Focused       65   0.460985   0.010783   0.813303        1.0
# 3    DCMR-Focused       66   0.667572   0.040039   0.888339        1.0
# 4    DCMR-Focused       67   0.767703   0.048773   0.807846        1.0
# ..            ...      ...        ...        ...        ...        ...
# 121  DCMR-Focused      240   0.593120   0.908754   0.853059        1.0
# 122  DCMR-Focused      241   0.696932   0.564802   0.697382        1.0
# 123  DCMR-Focused      242   0.704011   0.233361   0.918050        1.0
# 124  DCMR-Focused      243   0.619925   0.670872   0.724961        1.0
# 125  DCMR-Focused      244   0.362216   0.727592   0.733297        1.0
#
# [126 rows x 6 columns]

# %%
B_labels = [
    r'$\beta_\mathrm{enc}^{I}$',
    r'$\beta_\mathrm{enc}^{D}$',
    r'$\beta_\mathrm{rec}^{I}$',
    r'$\beta_\mathrm{rec}^{D}$',
]
B_subset['phase'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'enc',
        'B_enc_use': 'enc',
        'B_rec_loc': 'rec',
        'B_rec_use': 'rec',
    }
)
B_subset['sublayer'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'I',
        'B_enc_use': 'D',
        'B_rec_loc': 'I',
        'B_rec_use': 'D',
    }
)
fig, ax = plt.subplots(figsize=(5, 4))
statplot.plot_swarm_bar(
    B_subset,
    x='phase',
    y='value',
    hue='sublayer',
    point_kind='strip',
    light=light,
    dark=dark,
    dodge=True,
    bar_kws={'capsize': 0.2, 'clip_on': False},
    point_kws={'size': 4, 'alpha': 0.5, 'jitter': 0.2},
    legend=False,
    ax=ax,
)
ax.set(ylim=(0, 1), ylabel='Parameter estimate')
ax.set_xticks(
    [0, 1], 
    [r'$\beta_\mathrm{enc}$', r'$\beta_\mathrm{rec}$'], 
    usetex=True, 
    fontfamily='helvetica',
    fontsize='x-large',
)
ax.tick_params(axis='x', length=0)
ax.set(ylim=(0, 1.08), yticks=np.arange(0, 1.2, 0.2))
ax.spines['left'].set_bounds(0, 1)
fig.legend(loc=(.3375, .9), prop={'size': 12}, ncol=3)
ax.yaxis.set_label_coords(-.1, 0.475)
fig.savefig(fig_dir / 'param_B.pdf')
# Out:
# LINO NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Create parameter tables

# %%
table, raw = reports.create_model_table(fit_dir, models, model_names, model_comp='xval')
table.to_latex(fig_dir / 'parameters_peers.tex', escape=False)
table
# Out:
#                           DCMR-Variable  DCMR-NonInteg DCMR-NonInteg-Focused  \
# $\phi_s$                    0.11 (0.00)    0.13 (0.00)           0.13 (0.00)
# $\phi_d$                    0.90 (0.03)    0.98 (0.04)           0.98 (0.04)
# $\beta_{\mathrm{enc}}$              ---            ---                   ---
# $\beta_{\mathrm{enc},I}$    0.51 (0.01)    0.55 (0.01)           0.55 (0.01)
# $\beta_{\mathrm{enc},D}$    0.50 (0.01)              1                     1
# $\beta_{\mathrm{start}}$    0.42 (0.01)    0.43 (0.01)           0.43 (0.01)
# $\beta_{\mathrm{rec}}$              ---            ---                   ---
# $\beta_{\mathrm{rec},I}$    0.76 (0.01)    0.83 (0.00)           0.83 (0.00)
# $\beta_{\mathrm{rec},D}$    0.70 (0.01)    0.41 (0.01)                     1
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)           0.01 (0.00)
# $\theta_r$                  0.42 (0.00)    0.42 (0.00)           0.42 (0.00)
# $w_1$                       0.72 (0.01)    0.98 (0.00)           0.99 (0.00)
# $\tau$                      0.15 (0.01)    0.21 (0.01)           0.21 (0.01)
# $L^{FC}$                            ---            ---                   ---
# $L^{FC}_I$                  0.31 (0.01)    0.42 (0.01)           0.42 (0.01)
# $L^{CF}$                            ---            ---                   ---
# $L^{CF}_I$                  0.55 (0.01)    0.62 (0.01)           0.62 (0.01)
# $A^{CF}$                    0.32 (0.01)    0.40 (0.01)           0.40 (0.01)
# $A^{FF}$                   -0.53 (0.02)   -0.45 (0.02)          -0.46 (0.01)
# $D^{FF}$                    0.30 (0.01)    0.44 (0.02)           0.43 (0.02)
# $k$                                  16             15                    14
# $\mathrm{log}(L)$         -21.29 (0.16)  -21.29 (0.15)         -21.30 (0.16)
#
#                            DCMR-Focused     CMR-MP16-L
# $\phi_s$                    0.10 (0.00)    0.16 (0.01)
# $\phi_d$                    0.88 (0.03)    0.97 (0.04)
# $\beta_{\mathrm{enc}}$              ---    0.55 (0.01)
# $\beta_{\mathrm{enc},I}$    0.50 (0.01)            ---
# $\beta_{\mathrm{enc},D}$    0.56 (0.01)            ---
# $\beta_{\mathrm{start}}$    0.45 (0.01)    0.42 (0.01)
# $\beta_{\mathrm{rec}}$              ---    0.83 (0.00)
# $\beta_{\mathrm{rec},I}$    0.73 (0.01)            ---
# $\beta_{\mathrm{rec},D}$              1            ---
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.42 (0.00)    0.42 (0.00)
# $w_1$                       0.80 (0.01)            ---
# $\tau$                      0.15 (0.01)    0.21 (0.01)
# $L^{FC}$                            ---    0.41 (0.01)
# $L^{FC}_I$                  0.30 (0.01)            ---
# $L^{CF}$                            ---    0.61 (0.01)
# $L^{CF}_I$                  0.52 (0.01)            ---
# $A^{CF}$                    0.34 (0.01)    0.40 (0.01)
# $A^{FF}$                   -0.53 (0.02)   -0.45 (0.02)
# $D^{FF}$                    0.29 (0.01)    0.46 (0.02)
# $k$                                  15             13
# $\mathrm{log}(L)$         -21.26 (0.16)  -21.28 (0.15)

# %%
# %load_ext watermark
# %watermark -v -iv
# Out:
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.9.0
#
# dcmr      : 1.0.0a0
# matplotlib: 3.10.8
# mindstorm : 0.11.2
# numpy     : 2.4.1
# pandas    : 3.0.0
# seaborn   : 0.13.2

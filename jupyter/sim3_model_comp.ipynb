# %% [markdown]
# # Plot model fit comparisons for simulation analysis 3

# %%
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import seaborn.objects as so
from mindstorm import statplot
from dcmr import framework
from dcmr import figures
from dcmr import reports

fit_dir = Path(os.environ['CFR_FITS'])
fig_dir = Path(os.environ['CFR_FIGURES']) / 'sim3'
os.makedirs(fig_dir, exist_ok=True)
figures.set_style()
# %matplotlib inline

# %%
_, stat = framework.comp_version_variants(fit_dir / 'merge')
stat
# Out:
# model
# cmrst_fea-cat_sem-context                                                    -33.293027
# cmrstb_fea-cat_sem-context_cue-integrative                                   -33.211604
# cmrstb_fea-cat_sem-context_cue-focused                                       -33.205688
# cmrst_fea-loc_sem-context                                                    -32.215023
# cmrstb_fea-loc_sem-context                                                   -32.211990
# cmrst_fea-use_sem-context                                                    -32.112514
# cmrstb_fea-use_sem-context_cue-integrative                                   -32.108567
# cmrstb_fea-use_sem-context_cue-focused                                       -32.098887
# cmrst_fea-cat-use_sem-context                                                -31.745599
# cmrstb_fea-cat-use_sem-context_cue-integrative                               -31.536401
# cmrstb_fea-cat-use_sem-context_cue-focused                                   -31.405336
# cmrst_fea-loc-use_sem-context                                                -31.026398
# cmrstb_fea-loc-use_sem-context_cue-integrative                               -30.806924
# cmrstb_fea-loc-use_sem-context_cue-focused                                   -30.768706
# cmrst_fea-loc-cat_sem-context                                                -30.578863
# cmrst_fea-loc-cat-use_sem-context                                            -30.477753
# cmrstb_fea-loc-cat_sem-context_cue-integrative                               -30.382392
# cmrstb_fea-loc-cat_sem-context_cue-focused                                   -30.353468
# cmrsitb_fea-loc-cat-use_sem-item                                             -30.343445
# cmrsitb_fea-loc-cat-use_sem-item_dis-loc                                     -30.342955
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc-cat_sub-block        -30.315695
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-cat_sub-block            -30.301089
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc-cat                  -30.300582
# cmrsitb_fea-loc-cat-use_sem-item_sub-block                                   -30.294005
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_sub-list-block               -30.288989
# cmrsitb_fea-loc-cat-use_sem-item_dis-loc_sub-block                           -30.287543
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc                        -30.282341
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc                      -30.278469
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_sub-block                    -30.277382
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc-cat_sub-list-block   -30.276747
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc_sub-list               -30.276714
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-cat_sub-block              -30.275217
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc-cat_sub-list         -30.274973
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc_sub-block            -30.273754
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-cat_sub-list             -30.269261
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-cat                      -30.266816
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc_sub-list             -30.264584
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_sub-list-block                 -30.262509
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc-cat_sub-block          -30.262217
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc_sub-block              -30.260604
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc-cat_sub-list-block     -30.259941
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-cat                        -30.259228
# cmrstb_fea-loc-cat-use_sem-context_cue-integrative                           -30.256417
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc-cat                    -30.254416
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused                              -30.253477
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc_sub-list-block         -30.251944
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-cat_sub-list-block       -30.251882
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_dis-loc_sub-list-block       -30.251780
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused                                -30.250803
# cmrsitb_fea-loc-cat-use_sem-item_sub-list-block                              -30.246378
# cmrsitb_fea-loc-cat-use_sem-item_dis-loc_sub-list-block                      -30.241548
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_sub-list                       -30.240992
# cmrsitb_fea-loc-cat-use_sem-context_cue-focused_sub-list                     -30.239589
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_sub-block                      -30.237116
# cmrsitb_fea-loc-cat-use_sem-item_dis-loc_sub-list                            -30.231454
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-cat_sub-list-block         -30.227940
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-loc-cat_sub-list           -30.225875
# cmrsitb_fea-loc-cat-use_sem-split_cue-focused_dis-cat_sub-list               -30.216894
# cmrstb_fea-loc-cat-use_sem-context_cue-focused                               -30.208275
# cmrsitb_fea-loc-cat-use_sem-item_sub-list                                    -30.199702
# Name: logl_test_list, dtype: float64

# %%
res = framework.read_model_switchboard(fit_dir / 'switchboard4')

# %%
relabeled = res["dis"].replace({"cat": "C", "loc": "I", "loc-cat": "IC"})
res["dis"] = pd.Categorical(relabeled, categories=["none", "I", "C", "IC"], ordered=True)
res["sem"] = res["sem"].replace(
    {
        "context": "Semantic-context", 
        "item": "Semantic-item",
        "split": "Semantic-split",
    }
)

# %%
(
    so.Plot(res, y='logl', x='dis', color='sub', marker='sub')
    .facet('sem')
    .add(so.Dots(pointsize=8))
    .layout(size=(8, 4))
    .label(
        y='Cross-validated log likelihood', 
        x='Category shift disruption', 
        color='Additional sublayer',
    )
    .theme({'axes.labelsize': 'large'})
    .save(fig_dir / 'model_switchboard_comp.pdf', bbox_inches='tight')
)

# %% [markdown]
# ## Load model fits

# %%
included = ['DCMR-Disrupt', 'CMR-MP16-L']
models, model_names = framework.get_sim_models('cfr2', 'set2', included=included)

# %% [markdown]
# ## Plot best-fitting B parameters by sublayer

# %%
dark = sns.color_palette(
    'ch:start=0, rot=0.5, light=.7, dark=.1, gamma=.6, hue=.5', n_colors=3
)
dark
# Out:
# [(0.8676388027925326, 0.7871647534033639, 0.7634698745829795),
#  (0.6777292742424231, 0.5189671734934969, 0.6142788974816459),
#  (0.2668281999264471, 0.2224082818200638, 0.3359319635796286)]

# %%
light = sns.color_palette(
    'ch:start=0, rot=0.5, light=.7, dark=.1, gamma=.3, hue=.5', n_colors=3
)
light
# Out:
# [(0.9337854080610744, 0.886668854426149, 0.8727957979900954),
#  (0.8349525255609934, 0.7161842031132903, 0.7874859402046441),
#  (0.5231454706076213, 0.4636364754756973, 0.6157232084815651)]

# %%
B_model = models[model_names.index("DCMR-Disrupt")]
fit = framework.read_model_fits(fit_dir / 'merge', [B_model], ["DCMR-Disrupt"])
B_names = [
    'B_enc_loc',
    'B_enc_cat',
    'B_enc_use',
    'B_disrupt_cat',
    'B_rec_loc',
    'B_rec_cat',
    'B_rec_use',
]
B_subset = pd.melt(
    fit[B_names].reset_index(),
    id_vars='subject', 
    value_vars=B_names,
    var_name='parameter',
    value_name='value',
)
B_labels = [
    r'$\beta_\mathrm{enc}^{I}$',
    r'$\beta_\mathrm{enc}^{C}$',
    r'$\beta_\mathrm{enc}^{D}$',
    r'$\beta_\mathrm{disrupt}^{C}$',
    r'$\beta_\mathrm{rec}^{I}$',
    r'$\beta_\mathrm{rec}^{C}$',
    r'$\beta_\mathrm{rec}^{D}$',
]
B_subset['phase'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'enc',
        'B_enc_cat': 'enc',
        'B_enc_use': 'enc',
        'B_disrupt_cat': 'disrupt',
        'B_rec_loc': 'rec',
        'B_rec_cat': 'rec',
        'B_rec_use': 'rec',
    }
)
B_subset['sublayer'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'I',
        'B_enc_cat': 'C',
        'B_enc_use': 'D',
        'B_disrupt_cat': 'C',
        'B_rec_loc': 'I',
        'B_rec_cat': 'C',
        'B_rec_use': 'D',
    }
)
B_subset['phase'] = pd.Categorical(
    B_subset['phase'], 
    categories=['enc', 'disrupt', 'rec'], 
    ordered=True,
)

# %%
fig, ax = plt.subplots(figsize=(6, 4))
statplot.plot_swarm_bar(
    B_subset,
    x='phase',
    y='value',
    hue='sublayer',
    point_kind='strip',
    light=light,
    dark=dark,
    dodge=True,
    bar_kws={'capsize': 0.2, 'clip_on': False},
    point_kws={'size': 4},
    legend=False,
    ax=ax,
)
ax.set(ylim=(0, 1), ylabel='Parameter estimate')
ax.set_xticks(
    [0, 1, 2], 
    [r'$\beta_{enc}$', r'$\beta_{disrupt}$', r'$\beta_{rec}$'], 
    usetex=True, 
    fontfamily='helvetica',
    fontsize='x-large',
)
ax.tick_params(axis='x', length=0)
ax.set(ylim=(0, 1.08), yticks=np.arange(0, 1.2, 0.2))
ax.spines['left'].set_bounds(0, 1)
fig.legend(loc=(.3375, .9), prop={'size': 12}, ncol=3)
ax.yaxis.set_label_coords(-.1, 0.475)
fig.savefig(fig_dir / 'param_B.pdf')
# Out:
# LINO NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Create parameter tables

# %%
table, orig = reports.create_model_table(
    fit_dir / 'merge', models, model_names, model_comp='xval'
)
table.to_latex(fig_dir / 'parameters3.tex', escape=False)
table
# Out:
#                                DCMR-Disrupt     CMR-MP16-L
# $\phi_s$                        0.01 (0.00)    0.02 (0.00)
# $\phi_d$                        1.55 (0.19)    1.56 (0.18)
# $\beta_{\mathrm{enc}}$                  ---    0.55 (0.02)
# $\beta_{\mathrm{enc},I}$        0.51 (0.02)            ---
# $\beta_{\mathrm{enc},C}$        0.34 (0.04)            ---
# $\beta_{\mathrm{enc},D}$        0.63 (0.04)            ---
# $\beta_{\mathrm{start}}$        0.56 (0.04)    0.70 (0.05)
# $\beta_{\mathrm{rec}}$                  ---    0.84 (0.01)
# $\beta_{\mathrm{rec},I}$        0.72 (0.02)            ---
# $\theta_s$                      0.01 (0.00)    0.01 (0.00)
# $\theta_r$                      0.32 (0.01)    0.32 (0.01)
# $w_1$                           0.87 (0.02)            ---
# $w_2$                           0.10 (0.02)            ---
# $s_1$                           0.52 (0.04)    0.38 (0.02)
# $\tau$                          0.07 (0.01)    0.05 (0.01)
# $\beta_{\mathrm{disrupt},C}$    0.47 (0.05)            ---
# $L^{FC}$                                ---    0.08 (0.02)
# $L^{FC}_I$                      0.08 (0.02)            ---
# $L^{CF}$                                ---    0.08 (0.02)
# $L^{CF}_I$                      0.08 (0.02)            ---
# $A^{CF}$                        0.43 (0.03)    0.33 (0.03)
# $A^{FF}$                       -0.25 (0.06)   -0.17 (0.04)
# $D^{FF}$                        0.05 (0.01)    0.07 (0.02)
# $k$                                      19             14
# $\mathrm{log}(L)$             -30.22 (0.54)  -30.20 (0.54)

# %%
# %load_ext watermark
# %watermark -v -iv
# Out:
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.9.0
#
# dcmr      : 1.0.0a0
# matplotlib: 3.10.8
# mindstorm : 0.11.2
# numpy     : 2.4.1
# pandas    : 3.0.0
# seaborn   : 0.13.2
